# %% [markdown]
# # Cleaning Data of Ai Impact On Jobs 2030 Prediction

# %%
import pandas as pd

# %%
df = pd.read_csv('AI_Impact_on_Jobs_2030.csv')

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %%
df.dropna(inplace=True)

# %%
df.columns

# %%
df['Job_Title'].value_counts()
